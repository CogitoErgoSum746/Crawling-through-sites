# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('Book1.csv') 
dataset=data.drop(columns='ID',index=[7,20,107],inplace=True)
dataset

# %%
datalinks=dataset['URL'].tolist()

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
titleCollection=[]
pCollection=[]

class Pagination(scrapy.Spider):
    name = 'Pagination'
    start_urls = datalinks
    
    custom_settings={
        'DOWNLOAD_DELAY': 0.25,
        'CONCURRENT_REQUESTS_PER_DOMAIN': 1
    }

    def parse(self, response):
        global titleCollection,pCollection
        
        if response.status == 200:
            killo=response.css('title::text').get()
            killo2=response.css('p::text').getall()
            pCollection.append(killo2)
            titleCollection.append(killo)
        
#         if response.status == 404:
#             pCollection.append([""])
#             titleCollection.append("")

process=CrawlerProcess({
    'USER_AGENT':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
})
process.crawl(Pagination)
process.start()
# Out:
# 2022-12-10 01:58:27 [scrapy.utils.log] INFO: Scrapy 2.6.2 started (bot: scrapybot)
# 2022-12-10 01:58:27 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.14, cssselect 1.1.0, parsel 1.6.0, w3lib 1.21.0, Twisted 22.2.0, Python 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 22.0.0 (OpenSSL 1.1.1q  5 Jul 2022), cryptography 37.0.1, Platform Windows-10-10.0.22621-SP0
# 2022-12-10 01:58:27 [scrapy.crawler] INFO: Overridden settings:
# {'CONCURRENT_REQUESTS_PER_DOMAIN': 1,
#  'DOWNLOAD_DELAY': 0.25,
#  'USER_AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
#                '(KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
# 2022-12-10 01:58:27 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-12-10 01:58:27 [scrapy.extensions.telnet] INFO: Telnet Password: db07ae1e482ecd03
# 2022-12-10 01:58:27 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2022-12-10 01:58:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-12-10 01:58:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-12-10 01:58:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-12-10 01:58:28 [scrapy.core.engine] INFO: Spider opened
# 2022-12-10 01:58:29 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-12-10 01:58:29 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-12-10 01:58:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/> (referer: None)
# 2022-12-10 01:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/> (referer: None)
# 2022-12-10 01:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/> (referer: None)
# 2022-12-10 01:58:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/> (referer: None)
# 2022-12-10 01:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/> (referer: None)
# 2022-12-10 01:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/> (referer: None)
# 2022-12-10 01:58:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/> (referer: None)
# 2022-12-10 01:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-machine-learning-will-affect-your-business/> (referer: None)
# 2022-12-10 01:58:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/deep-learning-impact-on-areas-of-e-learning/> (referer: None)
# 2022-12-10 01:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-to-protect-future-data-and-its-privacy-blackcoffer/> (referer: None)
# 2022-12-10 01:58:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-machines-ai-automations-and-robo-human-are-effective-in-finance-and-banking/> (referer: None)
# 2022-12-10 01:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/ai-human-robotics-machine-future-planet-blackcoffer-thinking-jobs-workplace/> (referer: None)
# 2022-12-10 01:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-ai-will-change-the-world-blackcoffer/> (referer: None)
# 2022-12-10 01:58:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/future-of-work-how-ai-has-entered-the-workplace/> (referer: None)
# 2022-12-10 01:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/ai-tool-alexa-google-assistant-finance-banking-tool-future/> (referer: None)
# 2022-12-10 01:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/ai-healthcare-revolution-ml-technology-algorithm-google-analytics-industrialrevolution/> (referer: None)
# 2022-12-10 01:58:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/all-you-need-to-know-about-online-marketing/> (referer: None)
# 2022-12-10 01:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/evolution-of-advertising-industry/> (referer: None)
# 2022-12-10 01:58:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-data-analytics-can-help-your-business-respond-to-the-impact-of-covid-19/> (referer: None)
# 2022-12-10 01:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/environmental-impact-of-the-covid-19-pandemic-lesson-for-the-future/> (referer: None)
# 2022-12-10 01:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-data-analytics-and-ai-are-used-to-halt-the-covid-19-pandemic/> (referer: None)
# 2022-12-10 01:58:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/difference-between-artificial-intelligence-machine-learning-statistics-and-data-mining/> (referer: None)
# 2022-12-10 01:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-python-became-the-first-choice-for-data-science/> (referer: None)
# 2022-12-10 01:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-google-fit-measure-heart-and-respiratory-rates-using-a-phone/> (referer: None)
# 2022-12-10 01:58:39 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/what-is-the-future-of-mobile-apps/> (referer: None)
# 2022-12-10 01:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/impact-of-ai-in-health-and-medicine/> (referer: None)
# 2022-12-10 01:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/telemedicine-what-patients-like-and-dislike-about-it/> (referer: None)
# 2022-12-10 01:58:40 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/how-we-forecast-future-technologies/> (referer: None)
# 2022-12-10 01:58:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/can-robots-tackle-late-life-loneliness/> (referer: None)
# 2022-12-10 01:58:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/embedding-care-robots-into-society-socio-technical-considerations/> (referer: None)
# 2022-12-10 01:58:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/management-challenges-for-future-digitalization-of-healthcare-services/> (referer: None)
# 2022-12-10 01:58:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/are-we-any-closer-to-preventing-a-nuclear-holocaust/> (referer: None)
# 2022-12-10 01:58:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/will-technology-eliminate-the-need-for-animal-testing-in-drug-development/> (referer: None)
# 2022-12-10 01:58:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/will-we-ever-understand-the-nature-of-consciousness/> (referer: None)
# 2022-12-10 01:58:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/will-we-ever-colonize-outer-space/> (referer: None)
# 2022-12-10 01:58:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/what-is-the-chance-homo-sapiens-will-survive-for-the-next-500-years/> (referer: None)
# 2022-12-10 01:58:43 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/why-does-your-business-need-a-chatbot
05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/coronavirus-disease-covid-19-effect-the-impact-and-role-of-mass-media-during-the-pandemic/> (referer: None)
# 2022-12-10 01:59:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/should-people-wear-fabric-gloves-seeking-evidence-regarding-the-differential-transfer-of-covid-19-or-coronaviruses-generally-between-surfaces/> (referer: None)
# 2022-12-10 01:59:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/why-is-there-a-severe-immunological-and-inflammatory-explosion-in-those-affected-by-sarms-covid-19/> (referer: None)
# 2022-12-10 01:59:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/what-do-you-think-is-the-lesson-or-lessons-to-be-learned-with-covid-19/> (referer: None)
# 2022-12-10 01:59:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/coronavirus-the-unexpected-challenge-for-the-european-union/> (referer: None)
# 2022-12-10 01:59:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/industrial-revolution-4-0-pros-and-cons/> (referer: None)
# 2022-12-10 01:59:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy/> (referer: None)
# 2022-12-10 01:59:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-indian-economy-2/> (referer: None)
# 2022-12-10 01:59:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/impact-of-covid-19coronavirus-on-the-indian-economy/> (referer: None)
# 2022-12-10 01:59:08 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/impact-of-covid-19-coronavirus-on-the-global-economy/> (referer: None)
# 2022-12-10 01:59:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/blockchain-in-fintech/> (referer: None)
# 2022-12-10 01:59:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/blockchain-for-payments/> (referer: None)
# 2022-12-10 01:59:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/the-future-of-investing/> (referer: None)
# 2022-12-10 01:59:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/big-data-analytics-in-healthcare/> (referer: None)
# 2022-12-10 01:59:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/business-analytics-in-the-healthcare-industry/> (referer: None)
# 2022-12-10 01:59:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://insights.blackcoffer.com/challenges-and-opportunities-of-big-data-in-healthcare/> (referer: None)
# 2022-12-10 01:59:10 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-12-10 01:59:10 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 40493,
#  'downloader/request_count': 111,
#  'downloader/request_method_count/GET': 111,
#  'downloader/response_bytes': 3329249,
#  'downloader/response_count': 111,
#  'downloader/response_status_count/200': 111,
#  'elapsed_time_seconds': 41.614343,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 12, 9, 20, 29, 10, 908275),
#  'httpcompression/response_bytes': 18709955,
#  'httpcompression/response_count': 111,
#  'log_count/DEBUG': 112,
#  'log_count/INFO': 10,
#  'response_received_count': 111,
#  'scheduler/dequeued': 111,
#  'scheduler/dequeued/memory': 111,
#  'scheduler/enqueued': 111,
#  'scheduler/enqueued/memory': 111,
#  'start_time': datetime.datetime(2022, 12, 9, 20, 28, 29, 293932)}
# 2022-12-10 01:59:10 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
print(len(titleCollection))
print(len(pCollection))
# Out:
# 111
# 111

# %%
import nltk
from nltk import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
sw=stopwords.words('english')

# %%
with open('StopWords\StopWords_Auditor.txt') as f:
    StopWords_Auditor = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_Currencies.txt') as f:
    StopWords_Currencies = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_DatesandNumbers.txt') as f:
    StopWords_DatesandNumbers = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_Generic.txt') as f:
    StopWords_Generic = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_GenericLong.txt') as f:
    StopWords_GenericLong = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_Geographic.txt') as f:
    StopWords_Geographic = [line.rstrip('\n') for line in f]
with open('StopWords\StopWords_Names.txt') as f:
    StopWords_Names = [line.rstrip('\n') for line in f]
with open('MasterDictionary/negative_words.txt','r') as f:
    negative_words = [line.rstrip('\n') for line in f]
with open('MasterDictionary\positive-words.txt') as f:
    positive_words = [line.rstrip('\n') for line in f]

# %%
import string
punc=string.punctuation

def listConcat(list):
        mila=""
        for x in list:
            mila=mila+x+' '
        return mila

def bucketTokenize(record1):
        record2=word_tokenize(record1)
        unique_list=list(set(record2))
        punc_removed=[i for i in unique_list if i not in punc]
        return punc_removed

# %%
def checkStopWords(list):
    filter1=[i for i in list if i not in StopWords_Auditor]
    filter2=[i for i in filter1 if i not in StopWords_Currencies]
    filter3=[i for i in filter2 if i not in StopWords_DatesandNumbers]
    filter4=[i for i in filter3 if i not in StopWords_Generic]
    filter5=[i for i in filter4 if i not in StopWords_GenericLong]
    filter6=[i for i in filter5 if i not in StopWords_Geographic]
    filter7=[i for i in filter6 if i not in StopWords_Names]
    return filter7

# %%
pCollectionAppended=[]
text_body_tokens=[]
final_text=[]

# %%
for x in pCollection:
    pCollectionAppended.append(listConcat(x))
    
text_body_extract=[a + '. ' + b for a, b in zip(titleCollection, pCollectionAppended)] #--this is a list of strings

for x in text_body_extract:
    text_body_tokens.append(bucketTokenize(x)) #--this is a list of lists, each element corresponds to respective URL
    
for x in text_body_tokens:
    final_text.append(checkStopWords(x)) #--this is a list of lists after stopwords

# %%
len(final_text[100])
# Out:
# 91

# %%
POSITIVE_VALUE=[]
NEGATIVE_VALUE=[]

# %%
for x in final_text:
    POSITIVE_VALUE.append(len([i for i in x if i in positive_words]))
    NEGATIVE_VALUE.append(len([i for i in x if i in negative_words]))

# %%
print(len(POSITIVE_VALUE))
print(len(NEGATIVE_VALUE))
# Out:
# 111
# 111

# %%
POLARITY_SCORE=[]
SUBJECTIVITY_SCORE=[]

for i in range(len(POSITIVE_VALUE)):
    pol_score=(POSITIVE_VALUE[i]-NEGATIVE_VALUE[i])/(POSITIVE_VALUE[i]+NEGATIVE_VALUE[i] + 0.000001)
    POLARITY_SCORE.append(pol_score)

for i in range(len(POSITIVE_VALUE)):
    sub_score=(POSITIVE_VALUE[i]+NEGATIVE_VALUE[i])/(len(final_text) + 0.000001)
    SUBJECTIVITY_SCORE.append(sub_score)

# %%
# import sys
# !{sys.executable} -m pip install pyphen

# %%
from pyphen import Pyphen
p = Pyphen(lang='en_US')

COMPLEX_WORD_COUNT=[]

for x in final_text:
    count=0
    for i in x:
        if len(p.positions(i))+1>2:
            count+=1
    COMPLEX_WORD_COUNT.append(count)
SYLLABLE_COUNT_PER_WORD=COMPLEX_WORD_COUNT

# %%
AVERAGE_SENTENCE_LENGTH=[]

for x in text_body_extract:
    kim2=sent_tokenize(x)
    kim3=bucketTokenize(x)
    AVERAGE_SENTENCE_LENGTH.append(len(kim3)/len(kim2))
AVG_NUMBER_OF_WORDS_PER_SENTENCE=AVERAGE_SENTENCE_LENGTH

# %%
PERCENTAGE_OF_COMPLEX_WORDS=[]

for x in range(len(COMPLEX_WORD_COUNT)):
    PERCENTAGE_OF_COMPLEX_WORDS.append(COMPLEX_WORD_COUNT[x]/len(text_body_tokens[x]))

# %%
FOG_INDEX=[]

for x in range(len(COMPLEX_WORD_COUNT)):
    FOG_INDEX.append(0.4*(AVERAGE_SENTENCE_LENGTH[x] + PERCENTAGE_OF_COMPLEX_WORDS[x]))

# %%
WORD_COUNT=[]

for x in final_text:
    filtered_text=[i for i in x if i not in sw]
    WORD_COUNT.append(len(filtered_text))

# %%
# POLARITY_SCORE
# SUBJECTIVITY_SCORE
# COMPLEX_WORD_COUNT
# AVERAGE_SENTENCE_LENGTH
# PERCENTAGE_OF_COMPLEX_WORDS
# FOG_INDEX
# AVG_NUMBER_OF_WORDS_PER_SENTENCE
# WORD_COUNT

# %%
PERSONAL_PRONOUNS=[]

import re

for x in text_body_extract:
    res=re.findall('I|we|my|ours|us',x)
    res2=re.findall('US',x)
    PERSONAL_PRONOUNS.append(len(res)-len(res2))

# %%
AVG_WORD_LENGTH=[]

for x in text_body_extract:
    char_count=len(x) 
    words_count=len(x.strip().split(" "))
    AVG_WORD_LENGTH.append(char_count/words_count)

# %%
url_id=dataset['URL_ID'].tolist()   # 'URL_ID':url_id[:111],'URL':datalinks[:111]
final_dataset=pd.DataFrame({'URL_ID':url_id,'URL':datalinks,'POSITIVE VALUE':POSITIVE_VALUE,'NEGATIVE VALUE':NEGATIVE_VALUE,'POLARITY SCORE':POLARITY_SCORE,'SUBJECTIVITY SCORE':SUBJECTIVITY_SCORE,'AVERAGE SENTENCE LENGTH':AVERAGE_SENTENCE_LENGTH,'PERCENTAGE OF COMPLEX WORDS':PERCENTAGE_OF_COMPLEX_WORDS,'FOG INDEX':FOG_INDEX,'AVG NUMBER OF WORDS PER SENTENCE':AVG_NUMBER_OF_WORDS_PER_SENTENCE,'COMPLEX WORD COUNT':COMPLEX_WORD_COUNT,'WORD COUNT':WORD_COUNT,'SYLLABLE PER WORD':SYLLABLE_COUNT_PER_WORD,'PERSONAL PRONOUNS':PERSONAL_PRONOUNS,'AVG WORD LENGTH':AVG_WORD_LENGTH})
final_dataset.head()
# Out:
#    URL_ID                                                URL  POSITIVE VALUE  \
# 0      37  https://insights.blackcoffer.com/ai-in-healthc...              43
# 1      38  https://insights.blackcoffer.com/what-if-the-c...              38
# 2      39  https://insights.blackcoffer.com/what-jobs-wil...              48
# 3      40  https://insights.blackcoffer.com/will-machine-...              34
# 4      41  https://insights.blackcoffer.com/will-ai-repla...              34
#
#    NEGATIVE VALUE  POLARITY SCORE  SUBJECTIVITY SCORE  \
# 0              25        0.264706            0.612613
# 1              29        0.134328            0.603604
# 2              25        0.315068            0.657658
# 3              18        0.307692            0.468468
# 4              20        0.259259            0.486486
#
#    AVERAGE SENTENCE LENGTH  PERCENTAGE OF COMPLEX WORDS  FOG INDEX  \
# 0                11.229730                     0.315283   4.618005
# 1                 7.358025                     0.226510   3.033814
# 2                 8.500000                     0.306430   3.522572
# 3                 6.844444                     0.227273   2.828687
# 4                 9.820513                     0.246736   4.026900
#
#    AVG NUMBER OF WORDS PER SENTENCE  COMPLEX WORD COUNT  WORD COUNT  \
# 0                         11.229730                 262         709
# 1                          7.358025                 135         439
# 2                          8.500000                 224         583
# 3                          6.844444                 140         459
# 4                          9.820513                 189         602
#
#    SYLLABLE PER WORD  PERSONAL PRONOUNS  AVG WORD LENGTH
# 0                262                 90         6.798060
# 1                135                 69         5.995050
# 2                224                 86         6.517570
# 3                140                114         5.866106
# 4                189                 93         6.216568

# %%
final_dataset.to_csv('final_output_2.csv',index=False)
